# %% [markdown]
# ## 2.8 爬虫常用类库3：元素提取利器BeautifulSoup

# %% [markdown]
# ### 2.8.1 安装BeautifulSoup

# %%
# !pip3 install beautifulsoup4

# %% [markdown]
# ### 2.8.2 安装解析器

# %%
# !pip3 install lxml
# !pip3 install html5lib

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2.8.3 BeautifulSoup使用方法

# %%
html_doc ="""
<html><head><title>The Dormouse's story</title></head>
<body>
<p class="title"><b>The Dormouse's story</b></p >

<p class="story">Once upon a time there were three little sisters;
    and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a > and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a >;
and they lived at the bottom of a well.</p >
<p class="story">...</p >
</body>
</html>
"""

# %% [markdown]
# ### 2.8.4 BeautifulSoup对象

# %% [markdown]
# BeautifulSoup将复杂HTML文档转换成一个复杂的树形结构，每个节点都是Python对象，所有对象可以归纳为4种：
# - Tag
# - NavigableString
# - BeautifulSoup
# - Comment

# %% [markdown]
# #### 1. Tag

# %% [markdown]
# Tag对象与XML或HTML原生文档中的标签相同，如`<title>、<a>、<p>`等，这些标签及其内容就构成了一个Tag对象。Tag对象使用BeautifulSoup对象加对应标签名来提取。
#
# Tag对象有很多属性和方法，其中最重要和常用的两个属性是name和attributes。
#
# 每个Tag可能包含多个属性，如Tag `<p class="title"><b>The Dormouse's story</b></p>` 中有一个class属性，值为“title”。属性的操作方式与字典相同。

# %% [markdown]
# #### 2.NavigableString

# %% [markdown]
# BeautifulSoup使用NavigableString类来包装Tag中的字符串，可以通过.string提取Tag中的字符串数据。

# %% [markdown]
# #### 3. BeautifulSoup

# %% [markdown]
# BeautifulSoup对象表示的是一个文档的全部内容。大部分时候，可以把它当作一个Tag对象。因为BeautifulSoup 对象并不是真正的HTML或XML的标签，所以它没有name和attribute属性。但有时查看它的.name属性是很有用的，所以BeautifulSoup对象被赋予了一个值为“[document]”的特殊属性.name。

# %% [markdown]
# #### 4. Comment

# %% [markdown]
# ### 2.8.5 遍历文档树

# %% [markdown]
# #### 1. 子节点

# %% [markdown]
# #### 2. 父节点

# %% [markdown]
# #### 3. 兄弟节点

# %% [markdown]
# #### 4. 前后节点

# %% [markdown]
# ### 2.8.6 搜索文档树

# %% [markdown]
# 获取到网页数据之后，接下来的核心工作就是提取、采集数据。BeautifulSoup提供了很多搜索数据的方法，本节着重介绍两个方法：find()和find_all()，其他方法读者可自行学习。

# %% [markdown]
# #### 1. 字符串筛选

# %% [markdown]
# #### 2. 正则表达式

# %% [markdown]
# #### 3. 列表

# %% [markdown]
# #### 4. True

# %% [markdown]
# #### 5. 自定义方法

# %% [markdown]
# #### 6. find_all() 方法

# %% [markdown]
# #### 7. find()方法
